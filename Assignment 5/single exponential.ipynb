# %%
#single exponential smoothing
from statsmodels.tsa.api import ExponentialSmoothing,SimpleExpSmoothing, Holt
import pandas as pd
import matplotlib.pyplot as plt
import numpy
import math

from statsmodels.tsa.holtwinters import ExponentialSmoothing
# prepare data
r = pd.read_csv("shampoo.csv")
# create class
data=list(r['Sales'])
model = SimpleExpSmoothing(data)
# fit model
model_fit = model.fit(smoothing_level=0.438721619,optimized=False)
# make prediction
yhat_se = model_fit.predict(0,35)
plt.plot(data,label="observed")
plt.plot(yhat_se,label="predicted")
plt.legend()
plt.show()

def Rms(f_t):
    mae=0#mean absolute error
    mape=0#mean absolute percentage error
    mse=0#mean square error
    rmse=0#root mean square error
    for i in range(len(f_t)):
        mae=mae+(abs(data[i]-f_t[i]))
        mape=mape+(abs(data[i]-f_t[i]))/f_t[i]
        mse=mse+((abs(data[i]-f_t[i])**2))
    mae=mae/(len(f_t))
    mape=(mape/len(f_t))*100
    mse=mse/(len(f_t))
    rmse=math.sqrt(mse)
    print("Root Mean square error",rmse)
    
Rms(yhat_se)
# Out:
# Root Mean square error 82.99464351866823
